# %%
# %load_ext autoreload

# %autoreload

import chart_studio.plotly as py
from plotly.subplots import make_subplots
import plotly.graph_objects as go

import plotly.figure_factory as ff
import pandas as pd
from core.ta.ta import load_data, add_base_indicators, get_volume_leves

DATA_PATH = "~/dev/DaseinTradingCore/data/"
symbol = "BTC-USDT"
tf = "4h"
title = f"{symbol}_{tf}"
file_name = f"{DATA_PATH}/candles/{title}.csv"

df = load_data(file_name)
df = add_base_indicators(df)


v_levels, df = get_volume_leves(df)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [3], line 11
#       9 import plotly.figure_factory as ff
#      10 import pandas as pd
# ---> 11 from ..core.ta.ta import load_data, add_base_indicators, get_volume_leves
#      13 DATA_PATH = "~/dev/DaseinTradingCore/data/"
#      14 symbol = "BTC-USDT"
#
# ImportError: attempted relative import with no known parent package

# %%
from tools.backtesting.data_processor import plot_df, add_candles, add_volumes, add_v_peaks

candles = add_candles(df)
v =add_volumes(df)

# %%
fig = make_subplots(
    rows=2,
    cols=1,
    shared_xaxes=True,
    vertical_spacing=0.005,
    row_heights=[0.75, 0.25],
)

fig.add_trace(add_candles(df), row=1, col=1)
fig.add_trace(add_volumes(df), row=2, col=1)
# fig.add_trace(add_v_peaks(df), row=2, col=1)
from tools.backtesting.data_processor import plot_df, add_candles, add_breakouts, append_volume_levels, get_price_levels, append_price_levels, append_breakouts, get_sup_resist_peaks, add_bound_levels
append_volume_levels(fig, v_levels)
_up, _down, levels = get_sup_resist_peaks(df)
add_bound_levels(df, levels.values)
add_breakouts(df)
append_price_levels(fig, df, get_price_levels(levels))
append_breakouts(fig, df)
fig
# Out:
# /Users/dasein/dev/DaseinTradingCore/src/core/ta/ta.py:71: FutureWarning:
#
# The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#
# /Users/dasein/dev/DaseinTradingCore/src/core/ta/ta.py:72: FutureWarning:
#
# The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#
# /Users/dasein/dev/DaseinTradingCore/src/core/ta/ta.py:99: FutureWarning:
#
# The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
